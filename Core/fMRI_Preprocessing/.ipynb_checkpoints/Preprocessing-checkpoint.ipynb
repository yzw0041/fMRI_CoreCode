# %% [markdown]
# ## Data Read and Preprocessing using SPM

# %%
# Import the SPM interface under the name spm
import nipype.interfaces.spm as spm

# %%
from nipype.pipeline.engine import Workflow, Node, MapNode
# Import the function 'maths' from the FSL interface
import nipype.interfaces.fsl as fsl

# %%
# What is the location of your experiment folder
experiment_dir = '/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC'

# What are the names of your subjects
subjects = ['sub-NDARAC349YUC','sub-NDARAC350BZ0','sub-NDARAC350XUM']

# What is the name of your working directory and output folder
output_dir =  '/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_output_firstSteps'
working_dir = '/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps'

# What are experiment specific parameters
number_of_slices = 60
TR = 0.8
smoothing_size = 8

# %%
import nipype.interfaces.freesurfer as freesurfer
from os.path import join as opj
from nipype.interfaces.spm import SliceTiming, Realign, Smooth
from nipype.interfaces.utility import IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.algorithms.rapidart import ArtifactDetect
from nipype.algorithms.misc import Gunzip
from nipype.pipeline.engine import Workflow, Node

# %%
gunzip = Node(Gunzip(), name="gunzip")
realign = Node(Realign(register_to_mean=True),
               name="realign")
art = Node(ArtifactDetect(norm_threshold=1,
                          zintensity_threshold=3,
                          mask_type='spm_global',
                          parameter_source='SPM'),
           name="art")
# Smooth - to smooth the images with a given kernel
smooth = Node(Smooth(fwhm=smoothing_size),
              name="smooth")

# %%
preproc = Workflow(name='preproc')
preproc.base_dir = opj(experiment_dir, working_dir)

# Connect all components of the preprocessing workflow
preproc.connect([(gunzip, realign, [('out_file', 'in_files')]),
#                  (sliceTiming, realign, [('timecorrected_files', 'in_files')]),
                 (realign, art, [('realigned_files', 'realigned_files'),
                                 ('mean_image', 'mask_file'),
                                 ('realignment_parameters',
                                  'realignment_parameters')]),
                 (realign, smooth, [('realigned_files', 'in_files')]),
                 ])

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id',
                                            'session_id']),
                  name="infosource")
subject_list = ['sub-NDARAC349YUC','sub-NDARAC350BZ0','sub-NDARAC350XUM']
session_list=['run-1','run-2']

infosource.iterables = [('subject_id', subject_list),
                        ('session_id', session_list)]
# SelectFiles
templates = {'func': '{subject_id}/func/{subject_id}_task-rest_{session_id}_bold.nii.gz'}
selectfiles = Node(SelectFiles(templates,
                               base_directory=experiment_dir),
                   name="selectfiles")

# Datasink
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# Use the following DataSink output substitutions
#substitutions = [('_subject_id', ''),
           #      ('_session_id_', '')]
#datasink.inputs.substitutions = substitutions

# Connect SelectFiles and DataSink to the workflow
preproc.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                            ('session_id', 'session_id')]),
                 (selectfiles, gunzip, [('func', 'in_file')]),
                 (realign, datasink, [('mean_image', 'realign.@mean'),
                                      ('realignment_parameters',
                                       'realign.@parameters'),
                                      ]),
                 (smooth, datasink, [('smoothed_files', 'smooth')]),
                 (art, datasink, [('outlier_files', 'art.@outliers'),
                                  ('plot_files', 'art.@plot'),
                                  ]),
                 ])

# %%
preproc.write_graph(graph2use='flat')
preproc.run('MultiProc', plugin_args={'n_procs': 2})
# Out:
# 180716-18:30:06,31 nipype.workflow INFO:
# 	 Generated workflow graph: /Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/graph.png (graph2use=flat, simple_form=True).
# 180716-18:30:06,54 nipype.workflow INFO:
# 	 Workflow preproc settings: ['check', 'execution', 'logging', 'monitoring']
# 180716-18:30:06,118 nipype.workflow INFO:
# 	 Running in parallel.
# 180716-18:30:06,122 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 180716-18:30:06,192 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-2_subject_id_sub-NDARAC350XUM/selectfiles".
# 180716-18:30:06,194 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-1_subject_id_sub-NDARAC350XUM/selectfiles".
# 180716-18:30:06,267 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")180716-18:30:06,267 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 180716-18:30:06,300 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 180716-18:30:06,301 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 180716-18:30:08,126 nipype.workflow INFO:
# 	 [Job 0] Completed (preproc.selectfiles).
# 180716-18:30:08,182 nipype.workflow INFO:
# 	 [Job 6] Completed (preproc.selectfiles).
# 180716-18:30:08,184 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 180716-18:30:08,264 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.gunzip" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-2_subject_id_sub-NDARAC350XUM/gunzip".
# 180716-18:30:08,267 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.gunzip" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-1_subject_id_sub-NDARAC350XUM/gunzip".
# 180716-18:30:08,293 nipype.workflow INFO:
# 	 [Node] Running "gunzip" ("nipype.algorithms.misc.Gunzip")
# 180716-18:30:08,298 nipype.workflow INFO:
# 	 [Node] Running "gunzip" ("nipype.algorithms.misc.Gunzip")
# 180716-18:30:10,126 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.gunzip
#                        * preproc.gunzip
# 180716-18:30:22,129 nipype.workflow INFO:
# 	 [Node] Finished "preproc.gunzip".180716-18:30:22,129 nipype.workflow INFO:
# 	 [Node] Finished "preproc.gunzip".
#
# 180716-18:30:24,132 nipype.workflow INFO:
# 	 [Job 1] Completed (preproc.gunzip).
# 180716-18:30:24,133 nipype.workflow INFO:
# 	 [Job 7] Completed (preproc.gunzip).
# 180716-18:30:24,135 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 180716-18:30:24,196 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.realign" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-2_subject_id_sub-NDARAC350XUM/realign".
# 180716-18:30:24,200 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.realign" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-1_subject_id_sub-NDARAC350XUM/realign".
# 180716-18:30:26,135 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.realign
#                        * preproc.realign
# 180716-18:30:37,622 nipype.workflow INFO:
# 	 [Node] Running "realign" ("nipype.interfaces.spm.preprocess.Realign")
# 180716-18:30:40,899 nipype.workflow INFO:
# 	 [Node] Running "realign" ("nipype.interfaces.spm.preprocess.Realign")
# 180716-18:34:09,594 nipype.workflow INFO:
# 	 [Node] Finished "preproc.realign".
# 180716-18:34:10,278 nipype.workflow INFO:
# 	 [Job 8] Completed (preproc.realign).
# 180716-18:34:10,280 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 6 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.realign
# 180716-18:34:10,336 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.smooth" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-1_subject_id_sub-NDARAC350XUM/smooth".
# 180716-18:34:10,367 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 180716-18:34:12,280 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 5 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.realign
# 180716-18:34:12,822 nipype.workflow INFO:
# 	 [Node] Finished "preproc.realign".
# 180716-18:34:14,282 nipype.workflow INFO:
# 	 [Job 2] Completed (preproc.realign).
# 180716-18:34:14,283 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 7 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.smooth
# 180716-18:34:14,344 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.smooth" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-2_subject_id_sub-NDARAC350XUM/smooth".
# 180716-18:34:14,381 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 180716-18:34:16,285 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 6 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
# 180716-18:38:13,730 nipype.workflow INFO:
# 	 [Node] Finished "preproc.smooth".
# 180716-18:38:14,452 nipype.workflow INFO:
# 	 [Job 3] Completed (preproc.smooth).
# 180716-18:38:14,454 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 6 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.smooth
# 180716-18:38:14,515 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.art" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-2_subject_id_sub-NDARAC350XUM/art".
# 180716-18:38:14,540 nipype.workflow INFO:
# 	 [Node] Running "art" ("nipype.algorithms.rapidart.ArtifactDetect")
# 180716-18:38:16,453 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 5 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.art
#                        * preproc.smooth
# /Users/posnerlab/miniconda3/lib/python3.6/site-packages/scipy/signal/signaltools.py:2535: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   coef, resids, rank, s = linalg.lstsq(A, newdata[sl])
# 180716-18:38:20,254 nipype.workflow INFO:
# 	 [Node] Finished "preproc.art".
# 180716-18:38:20,455 nipype.workflow INFO:
# 	 [Job 4] Completed (preproc.art).
# 180716-18:38:20,456 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 6 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.smooth
# 180716-18:38:20,531 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-2_subject_id_sub-NDARAC350XUM/datasink".
# 180716-18:38:20,555 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 180716-18:38:22,460 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 5 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.datasink
#                        * preproc.smooth
# 180716-18:38:28,841 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 180716-18:38:30,460 nipype.workflow INFO:
# 	 [Job 5] Completed (preproc.datasink).
# 180716-18:38:30,462 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.smooth
# 180716-18:38:30,527 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.art" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-1_subject_id_sub-NDARAC350XUM/art".
# 180716-18:38:30,554 nipype.workflow INFO:
# 	 [Node] Running "art" ("nipype.algorithms.rapidart.ArtifactDetect")
# 180716-18:38:32,460 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.art
#                        * preproc.smooth
# 180716-18:38:36,23 nipype.workflow INFO:
# 	 [Node] Finished "preproc.art".
# 180716-18:38:36,466 nipype.workflow INFO:
# 	 [Job 10] Completed (preproc.art).
# 180716-18:38:36,468 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.smooth
# 180716-18:38:36,531 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-2_subject_id_sub-NDARAC350BZ0/selectfiles".
# 180716-18:38:36,583 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 180716-18:38:36,614 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 180716-18:38:38,468 nipype.workflow INFO:
# 	 [Job 12] Completed (preproc.selectfiles).
# 180716-18:38:38,470 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.smooth
# 180716-18:38:38,521 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.gunzip" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-2_subject_id_sub-NDARAC350BZ0/gunzip".
# 180716-18:38:38,546 nipype.workflow INFO:
# 	 [Node] Running "gunzip" ("nipype.algorithms.misc.Gunzip")
# 180716-18:38:40,296 nipype.workflow INFO:
# 	 [Node] Finished "preproc.smooth".
# 180716-18:38:40,469 nipype.workflow INFO:
# 	 [Job 9] Completed (preproc.smooth).
# 180716-18:38:40,471 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.gunzip
# 180716-18:38:40,644 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-1_subject_id_sub-NDARAC350XUM/datasink".
# 180716-18:38:40,727 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 180716-18:38:42,472 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.datasink
#                        * preproc.gunzip
# 180716-18:38:51,126 nipype.workflow INFO:
# 	 [Node] Finished "preproc.gunzip".
# 180716-18:38:52,475 nipype.workflow INFO:
# 	 [Job 13] Completed (preproc.gunzip).
# 180716-18:38:52,477 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.datasink
# 180716-18:38:52,620 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.realign" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-2_subject_id_sub-NDARAC350BZ0/realign".
# 180716-18:38:54,278 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 180716-18:38:54,480 nipype.workflow INFO:
# 	 [Job 11] Completed (preproc.datasink).
# 180716-18:38:54,482 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.realign
# 180716-18:38:54,575 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-1_subject_id_sub-NDARAC350BZ0/selectfiles".
# 180716-18:38:55,304 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 180716-18:38:55,734 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 180716-18:38:56,481 nipype.workflow INFO:
# 	 [Job 18] Completed (preproc.selectfiles).
# 180716-18:38:56,483 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.realign
# 180716-18:38:56,578 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.gunzip" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-1_subject_id_sub-NDARAC350BZ0/gunzip".
# 180716-18:38:57,3 nipype.workflow INFO:
# 	 [Node] Running "gunzip" ("nipype.algorithms.misc.Gunzip")
# 180716-18:38:58,483 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.gunzip
#                        * preproc.realign
# 180716-18:39:04,665 nipype.workflow INFO:
# 	 [Node] Running "realign" ("nipype.interfaces.spm.preprocess.Realign")
# 180716-18:39:08,443 nipype.workflow INFO:
# 	 [Node] Finished "preproc.gunzip".
# 180716-18:39:08,489 nipype.workflow INFO:
# 	 [Job 19] Completed (preproc.gunzip).
# 180716-18:39:08,492 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * preproc.realign
# 180716-18:39:08,568 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.realign" in "/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC_workingdir_firstSteps/preproc/_session_id_run-1_subject_id_sub-NDARAC350BZ0/realign".
# 180716-18:39:10,490 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * preproc.realign
#                        * preproc.realign
# 180716-18:39:17,337 nipype.workflow INFO:
# 	 [Node] Running "realign" ("nipype.interfaces.spm.preprocess.Realign")

# %%
/Volumes/Gradient/Personal/yun/HBN/MRI/Site-CBIC/sub-NDARAC349YUC/func/sub-NDARAC349YUC_task-rest_run-2_bold.nii.gz
